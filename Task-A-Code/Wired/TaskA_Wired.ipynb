# %%
folder = 'taskA-wired-graphs'
# !rm -rf $folder
# !mkdir $folder

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('results.csv')
df.head()
# Out:
#    Nodes  Flows  ...  Delivery Ratio  Drop Ratio
# 0   60.0   30.0  ...           95.66        4.34
# 1   80.0   20.0  ...           97.57        2.43
# 2  100.0   20.0  ...           97.52        2.48
# 3   60.0   30.0  ...           95.34        4.66
# 4   60.0   30.0  ...           95.17        4.83
#
# [5 rows x 7 columns]

# %%
data = df.loc[(df['Flows'] == 20) & (df['Packets Per Second']==20)]
data = data.sort_values('Nodes')

metrics = ['Throughput', 'End to End Delay', 'Delivery Ratio', 'Drop Ratio']
ylabels = ['Throughput (Kbps)', 'End to End Delay (microseconds)', 'Delivery Ratio (percentage)',
           'Drop Ratio (percentage)']

for i, m in enumerate(metrics):
    plt.plot(data['Nodes'], data[m])
    plt.scatter(data['Nodes'], data[m])
    plt.xlabel("Number of Nodes")
    plt.ylabel(ylabels[i])
    plt.title(m+" vs Number of Nodes")
    plt.savefig(folder+'/'+m+" vs Number of Nodes"+".png", dpi=1200)
    plt.show()
    print("")

# %%
data = df.loc[(df['Nodes'] == 60) & (df['Packets Per Second']==20)]
data = data.sort_values('Flows')

metrics = ['Throughput', 'End to End Delay', 'Delivery Ratio', 'Drop Ratio']
ylabels = ['Throughput (Kbps)', 'End to End Delay (microseconds)', 'Delivery Ratio (percentage)',
           'Drop Ratio (percentage)']

for i, m in enumerate(metrics):
    plt.plot(data['Flows'], data[m])
    plt.scatter(data['Flows'], data[m])
    plt.xlabel("Number of Flows")
    plt.ylabel(ylabels[i])
    plt.title(m+" vs Number of Flows")
    plt.savefig(folder+'/'+m+" vs Number of Flows"+".png", dpi=1200)
    plt.show()
    print("")

# %%
data = df.loc[(df['Nodes'] == 60) & (df['Flows']==30)]
data = data.sort_values('Packets Per Second')

metrics = ['Throughput', 'End to End Delay', 'Delivery Ratio', 'Drop Ratio']
ylabels = ['Throughput (Kbps)', 'End to End Delay (microseconds)', 'Delivery Ratio (percentage)',
           'Drop Ratio (percentage)']

for i, m in enumerate(metrics):
    plt.plot(data['Packets Per Second'], data[m])
    plt.scatter(data['Packets Per Second'], data[m])
    plt.xlabel("Number of Packets Per Second")
    plt.ylabel(ylabels[i])
    plt.title(m+" vs Number of Packets Per Second")
    plt.savefig(folder+'/'+m+" vs Number of Packets Per Second"+".png", dpi=1200)
    plt.show()
    print("")

# %%
import shutil
shutil.make_archive(folder, 'zip', folder)
# Out:
# '/content/taskA-wired-graphs.zip'
